# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
LOG_DIR = "logs"
filename= "log-1527981230.9914725.txt"
path = os.path.join(LOG_DIR, filename)
data = pd.read_csv(path,skipinitialspace=True)

# %%
data
# Out:
#     epoch        time  test_loss  train_loss  test_accuracy  \
# 0       0   42.545005   0.776221    0.781833      20.000000
# 1       1  108.249427   0.440265    0.452834      26.578189
# 2       2  108.108636   0.421760    0.417927      32.448560
# 3       3  102.065537   0.395508    0.392773      35.164609
# 4       4  106.787885   0.429809    0.376933      29.967078
# 5       5  109.421394   0.584761    0.364740      22.137860
# 6       6  105.811789   0.408513    0.356134      36.672840
# 7       7  108.931768   0.419075    0.347629      36.037037
# 8       8  106.903993   0.476178    0.342637      32.788066
# 9       9  106.410136   0.463220    0.335701      34.010288
# 10     10  107.958061   0.444439    0.331320      36.325103
# 11     11  104.562487   0.480453    0.326506      35.436214
# 12     12  107.643689   0.598633    0.322244      26.251029
# 13     13  107.270601   0.476477    0.320914      38.207819
# 14     14  109.024503   0.530216    0.316410      33.096708
# 15     15  107.917305   0.429435    0.312072      39.652263
# 16     16  108.933871   0.591904    0.309983      33.520576
# 17     17  107.462950   0.498015    0.308064      30.065844
# 18     18  106.795418   0.613463    0.305335      29.893004
# 19     19  100.801543   0.532200    0.302917      35.199588
# 20     20  103.288081   0.505212    0.301046      36.759259
# 21     21  102.319457   0.660169    0.298488      25.635802
# 22     22  107.914378   0.670558    0.297794      29.627572
# 23     23  107.516016   0.564592    0.294001      24.911523
# 24     24  107.129039   0.496403    0.292774      37.368313
# 25     25  104.687690   0.814699    0.289648      21.841564
# 26     26  107.079085   1.025177    0.288304      26.014403
# 27     27  107.475993   0.727427    0.286797      29.255144
# 28     28  107.717421   0.556941    0.285999      22.335391
# 29     29  107.297745   0.604885    0.283372      28.355967
# 30     30  107.490705   0.506058    0.282250      38.874486
# 31     31  106.367443   0.595403    0.280023      39.376543
#
#     reconstruction_loss_train  reconstruction_loss_test
# 0                   66.996727                 59.841266
# 1                   28.673181                 34.687506
# 2                   26.897475                 36.095685
# 3                   25.750725                 26.919789
# 4                   18.354383                 27.266260
# 5                   14.032655                 29.424528
# 6                   13.219257                 18.626252
# 7                   12.362846                 32.334279
# 8                   11.222650                 25.913833
# 9                   10.378864                 20.797641
# 10                   9.873951                 36.237816
# 11                   9.489585                 20.238026
# 12                   9.284344                 20.765267
# 13                   9.176151                 54.750401
# 14                   8.885504                 24.973451
# 15                   8.792311                 25.216339
# 16                   8.671200                 20.013274
# 17                   8.522546                 34.686791
# 18                   8.328150                 25.769777
# 19                   8.203314                 21.242351
# 20                   7.978426                 28.338675
# 21                   7.865378                 28.857641
# 22                   7.750827                 44.122345
# 23                   7.587376                 42.046695
# 24                   7.558698                 20.427998
# 25                   7.414211                 52.473089
# 26                   7.354367                 26.701037
# 27                   7.224144                 36.397826
# 28                   7.168848                 22.787592
# 29                   7.094320                 32.141437
# 30                   6.998233                 24.833393
# 31                   6.939523                 32.662977

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
plt.xlim([0, 80])
plt.ylim([14.0, 45.0])
plt.plot(data.reconstruction_loss_train[2:], '--o', label='Test reconstruction loss')
plt.plot(data.reconstruction_loss_test[2:], '--o', label='Train reconstruction loss')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
plt.ylim([0,1])
plt.plot(data.test_loss, '--o', label='Test loss')
plt.plot(data.train_loss, '--o', label='Train loss')
plt.legend()

# %%
[len(data.test_accuracy),len(data.test_accuracy)]
# Out:
# [38, 38]

# %%
plt.figure(figsize=(20,10))
plt.ylim([99.4,99.7])
plt.xlim([0, len(data.test_accuracy)])
plt.plot([0,len(data.test_accuracy)], [99.5, 99.5], '--')
plt.plot(data.test_accuracy[1:], '--o')

# %%
plt.figure(figsize=(20,10))
plt.plot(data.time[1:])
plt.ylim([100,110])
# Out:
# (100, 110)
