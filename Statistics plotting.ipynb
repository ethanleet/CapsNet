# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
LOG_DIR = "logs"
filename= "log-1528067112.7609706.txt"
path = os.path.join(LOG_DIR, filename)
data = pd.read_csv(path,skipinitialspace=True)

# %%
data
# Out:
#     epoch        time  test_loss  train_loss  test_accuracy  \
# 0       0   43.636611   0.753887    0.784687      20.000000
# 1       1  108.508503   0.438985    0.427494      30.654321
# 2       2  110.444314   0.475898    0.388109      25.242798
# 3       3  108.377239   0.382343    0.371326      37.516461
# 4       4  105.658398   0.407664    0.358117      35.753086
# 5       5  107.737815   0.593943    0.350135      21.240741
# 6       6  110.922868   0.389593    0.342253      39.975309
# 7       7  108.807154   0.399468    0.334276      36.703704
# 8       8  108.502987   0.374042    0.327945      41.179012
# 9       0   45.750685   0.376565    0.351397      40.767490
# 10      1  107.111050   0.372454    0.317034      40.825103
# 11      2  114.859729   0.350544    0.312941      44.273663
# 12      3  112.314170   0.356997    0.310175      42.905350
# 13      4  112.995480   0.364836    0.309161      41.613169
# 14      5  109.905470   0.381121    0.307677      40.267490
# ...

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
# plt.xlim([0, 80])
# plt.ylim([0.0, 100.0])
plt.plot(data.reconstruction_loss_test[2:], '--o', label='Test reconstruction loss')
plt.plot(data.reconstruction_loss_train[2:], '--o', label='Train reconstruction loss')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
# plt.ylim([0,1])
plt.plot(data.test_loss[1:], '--o', label='Test loss')
plt.plot(data.train_loss[1:], '--o', label='Train loss')
plt.legend()

# %%
[len(data.test_accuracy),len(data.test_accuracy)]
# Out:
# [4, 4]

# %%
plt.figure(figsize=(20,10))
plt.ylim([99.4,99.7])
plt.xlim([0, len(data.test_accuracy)])
plt.plot([0,len(data.test_accuracy)], [99.5, 99.5], '--')
plt.plot(data.test_accuracy[1:], '--o')

# %%
plt.figure(figsize=(20,10))
plt.plot(data.time[1:])
# plt.ylim([100,110])
