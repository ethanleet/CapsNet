# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
LOG_DIR = "logs"
filename= "log-1527360302.5634003.txt"
path = os.path.join(LOG_DIR, filename)
data = pd.read_csv(path,skipinitialspace=True)

# %%
data
# Out:
#     epoch        time  test_loss  train_loss  test_accuracy  \
# 0       0    9.136736   0.005397    0.000372          99.51
# 1       1  102.516392   0.005377    0.000098          99.54
# 2       2  102.707812   0.005488    0.000103          99.52
# 3       3  102.915849   0.005281    0.000098          99.54
# 4       4  102.693303   0.005291    0.000070          99.56
# 5       5  103.032198   0.005172    0.000065          99.54
# 6       6  103.001389   0.005254    0.000091          99.56
# 7       7  102.682680   0.005232    0.000065          99.54
# 8       8  102.698422   0.005183    0.000115          99.54
# 9       9  102.709959   0.005279    0.000049          99.52
# 10     10  102.649527   0.005241    0.000058          99.56
# 11     11  102.663992   0.005202    0.000057          99.56
# 12     12  102.649855   0.005159    0.000061          99.52
# 13     13  102.773238   0.005198    0.000063          99.53
# 14     14  102.916875   0.005711    0.000067          99.48
# ...

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
plt.xlim([0, 80])
plt.ylim([0.04, 0.06])
plt.plot(data.reconstruction_loss_train[2:], '--o', label='Test reconstruction loss')
plt.plot(data.reconstruction_loss_test[2:], '--o', label='Train reconstruction loss')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
plt.ylim([0,0.02])
plt.plot(data.test_loss, '--o', label='Test loss')
plt.plot(data.train_loss, '--o', label='Train loss')
plt.legend()

# %%
[len(data.test_accuracy),len(data.test_accuracy)]
# Out:
# [72, 72]

# %%
plt.figure(figsize=(20,10))
plt.ylim([99.4,99.7])
plt.xlim([0, len(data.test_accuracy)])
plt.plot([0,len(data.test_accuracy)], [99.5, 99.5], '--')
plt.plot(data.test_accuracy[1:], '--o')

# %%
plt.figure(figsize=(20,10))
plt.plot(data.time[1:])
plt.ylim([100,110])
# Out:
# (100, 110)
