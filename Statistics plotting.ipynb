# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
LOG_DIR = "logs"
filename= "log-1527734125.593868.txt"
path = os.path.join(LOG_DIR, filename)
data = pd.read_csv(path,skipinitialspace=True)

# %%
data
# Out:
#     epoch        time  test_loss  train_loss  test_accuracy  \
# 0       0   10.629304   0.628874    0.631700          10.32
# 1       1  105.794788   0.058026    0.221808          97.47
# 2       2  106.518303   0.046872    0.047297          98.02
# 3       3  106.455956   0.035706    0.038489          98.76
# 4       4  106.389150   0.033334    0.034623          98.87
# 5       5  108.667832   0.030899    0.031932          99.17
# 6       6  104.360425   0.034872    0.029369          98.69
# 7       7  106.651666   0.025248    0.026957          99.19
# 8       8  105.840400   0.025840    0.024477          99.06
# 9       9  107.581773   0.026253    0.022885          99.01
# 10     10  101.653439   0.023216    0.021321          99.21
# 11     11  107.179086   0.021903    0.019873          99.27
# 12     12  104.522234   0.020351    0.018779          99.25
# 13     13  109.234006   0.019948    0.017728          99.30
# 14     14  107.891276   0.019745    0.016968          99.28
# 15     15  106.409271   0.018263    0.016000          99.44
# 16     16  105.085060   0.018032    0.015348          99.31
# 17     17  106.786706   0.018551    0.014682          99.29
# 18     18  110.849077   0.017043    0.014157          99.41
# 19     19  114.092006   0.015980    0.013542          99.40
# 20     20  114.292984   0.015737    0.012926          99.46
# 21     21  113.808790   0.015874    0.012043          99.36
# 22     22  113.907909   0.015743    0.011774          99.37
# 23     23  111.800160   0.014830    0.011326          99.50
# 24     24  105.624295   0.014659    0.011065          99.48
# 25     25  105.863222   0.014843    0.010745          99.40
# 26     26  106.197361   0.014200    0.010174          99.49
# 27     27  106.009672   0.014309    0.009891          99.40
# 28     28  106.204601   0.014715    0.009747          99.39
# 29     29  106.037138   0.014362    0.009282          99.36
# 30     30  106.110535   0.013932    0.009215          99.45
# 31     31  106.104158   0.013668    0.008851          99.41
# 32     32  105.757664   0.013674    0.008639          99.44
# 33     33  106.224169   0.013428    0.008448          99.48
# 34     34  106.126279   0.013428    0.008228          99.44
# 35     35  106.145741   0.013368    0.008077          99.47
# 36     36  106.210945   0.013093    0.007784          99.40
# 37     37  106.867283   0.012765    0.007647          99.44
#
#     reconstruction_loss_train  reconstruction_loss_test
# 0                  181.056564                179.801746
# 1                   51.570551                 42.652863
# 2                   41.838689                 40.920028
# 3                   40.911697                 40.002967
# 4                   40.059806                 39.364423
# 5                   38.759922                 37.798996
# 6                   36.822899                 35.668115
# 7                   34.352360                 32.318130
# 8                   31.334359                 30.207187
# 9                   29.393007                 28.614496
# 10                  27.968762                 27.315180
# 11                  26.499959                 25.703340
# 12                  25.116511                 24.356159
# 13                  24.153064                 23.690957
# 14                  23.263571                 22.848246
# 15                  22.439033                 22.111330
# 16                  21.876286                 21.542654
# 17                  21.356009                 21.136808
# 18                  20.832279                 20.412501
# 19                  20.224291                 19.702967
# 20                  19.485929                 19.046320
# 21                  18.735102                 18.498925
# 22                  18.294037                 18.361091
# 23                  17.932832                 17.790041
# 24                  17.657342                 17.404536
# 25                  17.333563                 17.227155
# 26                  16.954574                 16.813391
# 27                  16.609820                 16.547925
# 28                  16.329428                 16.343007
# 29                  16.041803                 16.124279
# 30                  15.818506                 15.734542
# 31                  15.468453                 15.443647
# 32                  15.168002                 15.191218
# 33                  14.874498                 14.942977
# 34                  14.643906                 14.738342
# 35                  14.431609                 14.679097
# 36                  14.169467                 14.424610
# 37                  14.007464                 14.125873

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
plt.xlim([0, 80])
plt.ylim([14.0, 45.0])
plt.plot(data.reconstruction_loss_train[2:], '--o', label='Test reconstruction loss')
plt.plot(data.reconstruction_loss_test[2:], '--o', label='Train reconstruction loss')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
plt.ylim([0,0.06])
plt.plot(data.test_loss, '--o', label='Test loss')
plt.plot(data.train_loss, '--o', label='Train loss')
plt.legend()

# %%
[len(data.test_accuracy),len(data.test_accuracy)]
# Out:
# [38, 38]

# %%
plt.figure(figsize=(20,10))
plt.ylim([99.4,99.7])
plt.xlim([0, len(data.test_accuracy)])
plt.plot([0,len(data.test_accuracy)], [99.5, 99.5], '--')
plt.plot(data.test_accuracy[1:], '--o')

# %%
plt.figure(figsize=(20,10))
plt.plot(data.time[1:])
plt.ylim([100,110])
# Out:
# (100, 110)
