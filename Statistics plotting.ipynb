# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
LOG_DIR = "logs"
filename= "log-1527984836.8212302.txt"
path = os.path.join(LOG_DIR, filename)
data = pd.read_csv(path,skipinitialspace=True)

# %%
data
# Out:
#     epoch        time  test_loss  train_loss  test_accuracy  \
# 0       0   42.090552   0.773501    0.781415      20.000000
# 1       1  111.324297   0.450793    0.561927      20.000000
# 2       2  108.258414   0.443384    0.442287      21.493827
# 3       3  114.834622   0.442167    0.440489      22.265432
# 4       4  118.868912   0.440145    0.439178      28.259259
# 5       5  118.743015   0.433272    0.434255      31.687243
# 6       6  111.383964   0.423442    0.422191      31.088477
# 7       7  109.201091   0.432503    0.408840      28.076132
# 8       8  108.565356   0.448794    0.399301      26.234568
# 9       9  109.797533   0.401359    0.393797      34.471193
# 10     10  104.099988   0.472424    0.389081      26.713992
# 11     11  108.370268   0.459045    0.382820      26.874486
# 12     12  108.922768   0.431560    0.380601      32.841564
# 13     13  116.434945   0.399374    0.376696      36.884774
# 14     14  109.449664   0.492129    0.372937      25.788066
# 15     15  108.114239   0.399488    0.369670      36.234568
# 16     16  107.635665   0.384743    0.366379      38.432099
# 17     17  108.769778   0.379938    0.363305      39.228395
# 18     18  108.212518   0.409584    0.360456      35.168724
# 19     19  108.750525   0.383140    0.357611      38.312757
# 20     20  108.333838   0.405952    0.355658      35.006173
# 21     21  108.470704   0.404091    0.353582      35.362140
# 22     22  111.401582   0.363980    0.349996      41.024691
# 23     23  111.591960   0.431338    0.346685      33.736626
# 24     24  111.014755   0.390493    0.343103      36.685185
# 25     25  109.212160   0.380644    0.341819      39.890947
# 26     26  108.942798   0.367025    0.337870      39.485597
# 27     27  105.787574   0.468918    0.336432      30.281893
# 28     28  109.197253   0.429176    0.335059      34.549383
# 29     29  109.047189   0.454629    0.333250      33.989712
# 30     30  108.385112   0.418379    0.331002      37.769547
# 31     31  109.887908   0.414699    0.330457      35.228395
# 32     32  108.832948   0.368430    0.327692      41.927984
#
#     reconstruction_loss_train  reconstruction_loss_test
# 0                   75.139816                 62.296828
# 1                   31.606012                 31.755538
# 2                   28.332790                 33.500451
# 3                   28.280911                 32.100058
# 4                   28.251317                 33.086705
# 5                   28.266088                 33.560894
# 6                   28.278984                 33.390194
# 7                   28.151921                 31.645452
# 8                   28.150191                 32.249675
# 9                   27.760096                 33.765342
# 10                  27.193267                 45.373339
# 11                  27.025929                 32.556546
# 12                  26.957300                 44.843426
# 13                  26.907617                 38.489913
# 14                  26.852143                 32.939752
# 15                  26.727938                 39.585377
# 16                  27.026952                 32.993490
# 17                  26.778546                 33.653377
# 18                  26.723129                 47.404706
# 19                  26.653076                 35.620882
# 20                  26.445350                 39.867957
# 21                  25.209273                 40.161033
# 22                  23.934345                 27.022726
# 23                  21.326094                 37.709537
# 24                  17.948210                 21.672113
# 25                  16.193087                 21.304162
# 26                  15.104287                 21.953206
# 27                  14.517040                 20.655056
# 28                  14.170543                 18.859937
# 29                  13.816278                 29.766356
# 30                  13.605150                 19.968699
# 31                  13.362483                 17.497532
# 32                  12.991871                 40.175791

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
plt.xlim([0, 80])
plt.ylim([14.0, 45.0])
plt.plot(data.reconstruction_loss_test[2:], '--o', label='Test reconstruction loss')
plt.plot(data.reconstruction_loss_train[2:], '--o', label='Train reconstruction loss')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
plt.ylim([0,1])
plt.plot(data.test_loss, '--o', label='Test loss')
plt.plot(data.train_loss, '--o', label='Train loss')
plt.legend()

# %%
[len(data.test_accuracy),len(data.test_accuracy)]
# Out:
# [34, 34]

# %%
plt.figure(figsize=(20,10))
plt.ylim([99.4,99.7])
plt.xlim([0, len(data.test_accuracy)])
plt.plot([0,len(data.test_accuracy)], [99.5, 99.5], '--')
plt.plot(data.test_accuracy[1:], '--o')

# %%
plt.figure(figsize=(20,10))
plt.plot(data.time[1:])
plt.ylim([100,110])
# Out:
# (100, 110)
