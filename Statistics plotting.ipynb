# 227     61  178.500682   0.162391    0.094038      80.000000
# 228     62  178.176271   0.165493    0.094090      79.378601
# 229     63  178.268197   0.164372    0.093897      79.306584
# 230     64  178.557218   0.170292    0.094426      78.746914
# 231     65  177.132893   0.163003    0.094278      79.646091
#
#      reconstruction_loss_train  reconstruction_loss_test
# 0                    66.941498                 58.250653
# 1                    26.916285                 27.346714
# 2                    14.027635                 18.857145
# 3                    13.112400                 19.698725
# 4                    12.792635                 19.124840
# 5                    12.654078                 21.211562
# 6                    12.489892                 17.632151
# 7                    12.434978                 20.387747
# 8                    12.269147                 19.918524
# 9                    12.250650                 19.311698
# 10                   12.216856                 19.195549
# 11                   12.018187                 17.669987
# 12                   11.903463                 19.451312
# 13                   11.942446                 24.580318
# 14                   11.803112                 17.087460
# 15                   11.781491                 19.819103
# 16                   11.612552                 17.010159
# 17                   11.651926                 19.075679
# 18                   11.531079                 18.410925
# 19                   11.561507                 16.528293
# 20                   11.526320                 16.710392
# 21                   11.437242                 20.297836
# 22                   11.426269                 19.620188
# 23                   11.346952                 18.195242
# 24                   11.299233                 15.947616
# 25                   10.245406                 15.426531
# 26                   10.886640                 15.051939
# 27                   10.879857                 15.147557
# 28                   10.876049                 15.216888
# 29                   10.827801                 15.267861
# ..                         ...                       ...
# 202                  10.644745                 15.089312
# 203                  10.681649                 15.144320
# 204                  10.567549                 15.122897
# 205                  10.618311                 15.210345
# 206                  10.607315                 15.205169
# 207                  10.583995                 15.109323
# 208                  10.632644                 15.078301
# 209                  10.562281                 15.070838
# 210                  10.577139                 15.113614
# 211                  10.558163                 15.132027
# 212                  10.569264                 15.109519
# 213                  10.547887                 15.083230
# 214                  10.588944                 15.098135
# 215                  10.571978                 15.050404
# 216                  10.511552                 15.177865
# 217                  10.538425                 15.201046
# 218                  10.574902                 15.229361
# 219                  10.603249                 15.109529
# 220                  10.572153                 15.085959
# 221                  10.611735                 15.025351
# 222                  10.574247                 15.138170
# 223                  10.600911                 15.103230
# 224                  10.615131                 15.136351
# 225                  10.531417                 15.061761
# 226                  10.606774                 15.045731
# 227                  10.533660                 15.152537
# 228                  10.586788                 15.055132
# 229                  10.579395                 15.143227
# 230                  10.552030                 15.059597
# 231                  10.578925                 15.082846
#
# [232 rows x 7 columns]

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
# plt.xlim([0, 80])
# plt.ylim([0.0, 100.0])
plt.plot(data.reconstruction_loss_test[1:], '--o', label='Test reconstruction loss')
plt.plot(data.reconstruction_loss_train[1:], '--o', label='Train reconstruction loss')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
# plt.xlim([0,80])
plt.plot(data.test_loss[1:], '--o', label='Test loss')
plt.plot(data.train_loss[1:], '--o', label='Train loss')
plt.legend()

# %%
[len(data.test_accuracy),len(data.test_accuracy)]
# Out:
# [232, 232]

# %%
plt.figure(figsize=(20,10))
plt.xlim([0, len(data.test_accuracy)])
plt.plot([0,len(data.test_accuracy)], [99.5, 99.5], '--')
plt.plot(data.test_accuracy[0:], '--o')

# %%
plt.figure(figsize=(20,10))
plt.plot(data.time[1:])
# plt.ylim([100,110])
