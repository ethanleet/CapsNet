# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
LOG_DIR = "../logs"
filename= "log-1528586274.9812639.txt"
path = os.path.join(LOG_DIR, filename)
data = pd.read_csv(path,skipinitialspace=True)

# %%
data[-10:]
# Out:
#     epoch        time  test_loss  train_loss  test_accuracy  \
# 5       5  259.496573   0.318442    0.298484          66.38
# 6       6  259.695532   0.321509    0.280773          65.70
# 7       7  260.400717   0.307028    0.264445          67.85
# 8       8  259.294693   0.300207    0.249783          69.16
# 9       9  259.593918   0.303528    0.236630          68.65
# 10     10  249.599513   0.300386    0.222821          68.13
# 11     11  259.485189   0.295659    0.211525          69.62
# 12     12  259.798098   0.298408    0.199591          68.79
# 13     13  260.097884   0.298794    0.188163          69.09
# 14     14  259.979803   0.299961    0.176339          68.98
#
#     reconstruction_loss_train  reconstruction_loss_test  margin_loss_train  \
# 5                  112.022847                109.856172           0.242473
# 6                  108.197205                106.057309           0.226674
# 7                  104.355240                105.723018           0.212267
# 8                  101.217610                103.124551           0.199174
# 9                   98.484276                101.781792           0.187388
# 10                  96.779352                103.545596           0.174431
# 11                  94.907459                100.835754           0.164071
# 12                  93.212068                 99.039136           0.152985
# 13                  91.699595                102.536539           0.142313
# 14                  90.191509                 99.017624           0.131244
#
#     margin_loss_test
# 5           0.053242
# 6           0.054245
# 7           0.051353
# 8           0.050238
# 9           0.051044
# 10          0.050231
# 11          0.049550
# 12          0.050287
# 13          0.050012
# 14          0.050603

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
# plt.xlim([0, 80])
# plt.ylim([0.0, 100.0])
plt.plot(data.reconstruction_loss_test[0:], '--o', label='Test reconstruction loss')
plt.plot(data.reconstruction_loss_train[0:], '--o', label='Train reconstruction loss')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
# plt.xlim([0,80])
plt.plot(data.test_loss[0:], '--o', label='Test loss')
plt.plot(data.train_loss[0:], '--o', label='Train loss')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
# plt.xlim([0,80])
plt.plot(data.margin_loss_test[0:], '--o', label='Test loss')
plt.plot(data.margin_loss_train[0:], '--o', label='Train loss')
plt.legend()

# %%
[len(data.test_accuracy),len(data.test_accuracy)]
# Out:
# [9, 9]

# %%
plt.figure(figsize=(20,10))
plt.xlim([0, len(data.test_accuracy)])
plt.plot([0,len(data.test_accuracy)], [99.5, 99.5], '--')
plt.plot(data.test_accuracy[0:], '--o')

# %%
plt.figure(figsize=(20,10))
plt.plot(data.time[0:])
# plt.ylim([100,110])
