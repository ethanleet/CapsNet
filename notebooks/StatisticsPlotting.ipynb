# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
LOG_DIR = "logs"
filename= "log-FC_0.005.txt"
path = os.path.join(LOG_DIR, filename)
data = pd.read_csv(path,skipinitialspace=True)

# %%
data[-10:]
# Out:
#      epoch        time  test_loss  train_loss  test_accuracy  \
# 102    102  191.426055   0.244817    0.167839      78.065844
# 103    103  190.383717   0.248923    0.168315      76.526749
# 104    104  190.832926   0.241166    0.169221      77.203704
# 105    105  194.694996   0.243961    0.167330      77.625514
# 106    106  189.924529   0.236755    0.168321      78.084362
# 107    107  189.438903   0.249085    0.167296      76.508230
# 108    108  189.063359   0.244609    0.167970      76.979424
# 109    109  188.206736   0.236709    0.167941      78.633745
# 110    110  186.014158   0.251862    0.167115      75.164609
# 111    111  187.537541   0.233042    0.165749      78.452675
#
#      reconstruction_loss_train  reconstruction_loss_test
# 102                   5.780180                  9.358616
# 103                   5.742433                  9.180538
# 104                   5.836261                  9.260877
# 105                   5.825775                  9.629482
# 106                   5.846118                  9.562505
# 107                   5.783101                  9.404717
# 108                   5.854919                  9.293203
# 109                   5.816544                  9.657991
# 110                   5.844626                  9.319910
# 111                   5.758318                  9.293691

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
# plt.xlim([0, 80])
# plt.ylim([0.0, 100.0])
plt.plot(data.reconstruction_loss_test[0:], '--o', label='Test reconstruction loss')
plt.plot(data.reconstruction_loss_train[0:], '--o', label='Train reconstruction loss')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.title("Loss")
# plt.xlim([0,80])
plt.plot(data.test_loss[0:], '--o', label='Test loss')
plt.plot(data.train_loss[0:], '--o', label='Train loss')
plt.legend()

# %%
[len(data.test_accuracy),len(data.test_accuracy)]
# Out:
# [112, 112]

# %%
plt.figure(figsize=(20,10))
plt.xlim([0, len(data.test_accuracy)])
plt.plot([0,len(data.test_accuracy)], [99.5, 99.5], '--')
plt.plot(data.test_accuracy[0:], '--o')

# %%
plt.figure(figsize=(20,10))
plt.plot(data.time[0:])
# plt.ylim([100,110])
